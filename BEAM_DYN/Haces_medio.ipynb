# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pylab as plt
from matplotlib import cm
from matplotlib.cm import ScalarMappable
import matplotlib.patches as patches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

plt.rcParams['font.size'] = 13

# generate example data
import pandas as pd

#IMAN
ax = plt.gca()
rect = patches.Rectangle((-10,-10), 20,20,edgecolor = 'grey', facecolor = 'grey', fill = True,)
ax.add_patch(rect)

NUM_PART = 10
files = ['20P.txt', '20H2.txt','20H3.txt']
color = iter(cm.rainbow(np.linspace(0, 1, len(files))))

for file in files:
    data1 = pd.read_csv(file, sep = '\s+', header = None)
    data1 = pd.DataFrame(data1)
    c = next(color)  
    for particle in range(0, NUM_PART-1):
        cero = data1[data1[3] == particle]
        xp0 = cero[0]
        zp0 = cero[2]
        plt.plot(xp0,zp0, color = c)

plt.xlabel('X(mm)')
plt.ylabel('Z(mm)')
plt.title('Desviación en la dirección del protón, H2+ y H3+ a 20keV')
plt.ylim(-45,40)

#legend

legend_elements = [Line2D([0], [0], color='blueviolet', lw=2, label='Protón'),
                   Line2D([0], [0], color='LightGreen', lw=2, label='H2+'),
                   Line2D([0], [0], color='r', lw=2, label='H3+'),
                   Patch(facecolor='grey', edgecolor='grey', label='Imán')]

ax.legend(handles=legend_elements, loc='lower left')

plt.show()

# %%
## import numpy as np
from scipy.interpolate import griddata
import matplotlib.pylab as plt
from matplotlib import cm
from matplotlib.cm import ScalarMappable
import matplotlib.patches as patches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

plt.rcParams['font.size'] = 13

# generate example data
import pandas as pd

#IMAN
ax = plt.gca()
rect = patches.Rectangle((-10,-10), 20,20,edgecolor = 'grey', facecolor = 'grey', fill = True,)
ax.add_patch(rect)

NUM_PART = 10
files = ['15P.txt', '15H2.txt','15H3.txt']
color = iter(cm.rainbow(np.linspace(0, 1, len(files))))
for file in files:
    data1 = pd.read_csv(file, sep = '\s+', header = None)
    data1 = pd.DataFrame(data1)
    c = next(color)
    for particle in range(0, NUM_PART-1):
        cero = data1[data1[3] == particle]
        xp0 = cero[0]
        zp0 = cero[2]
        plt.plot(xp0,zp0, color = c ,label = 'Protoia')
        
plt.xlabel('X(mm)')
plt.ylabel('Z (mm)')
plt.title('Desviación en la dirección del protón, H2+ y H3+ a 15keV')
plt.ylim(-45,30)

#legend

legend_elements = [Line2D([0], [0], color='blueviolet', lw=2, label='Protón'),
                   Line2D([0], [0], color='LightGreen', lw=2, label='H2+'),
                   Line2D([0], [0], color='r', lw=2, label='H3+'),
                   Patch(facecolor='grey', edgecolor='grey', label='Imán')]

ax.legend(handles=legend_elements, loc='lower left')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pylab as plt
from matplotlib import cm
from matplotlib.cm import ScalarMappable
import matplotlib.patches as patches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

plt.rcParams['font.size'] = 13

# generate example data
import pandas as pd

#IMAN
ax = plt.gca()
rect = patches.Rectangle((-10,-10), 20,20,edgecolor = 'grey', facecolor = 'grey', fill = True,)
ax.add_patch(rect)

NUM_PART = 10
files = ['10P.txt', '10H2.txt','10H3.txt']
color = iter(cm.rainbow(np.linspace(0, 1, len(files))))
for file in files:
    data1 = pd.read_csv(file, sep = '\s+', header = None)
    data1 = pd.DataFrame(data1)
    c = next(color)
    for particle in range(0, NUM_PART-1):
        cero = data1[data1[3] == particle]
        xp0 = cero[0]
        zp0 = cero[2]
        plt.plot(xp0,zp0, color = c ,label = 'Protoia')

plt.xlabel('X(mm)')
plt.ylabel('Z (mm)')
plt.title('Desviación en la dirección del protón, H2+ y H3+ a 10keV')
plt.ylim(-45,23)

#legend

legend_elements = [Line2D([0], [0], color='blueviolet', lw=2, label='Protón'),
                   Line2D([0], [0], color='LightGreen', lw=2, label='H2+'),
                   Line2D([0], [0], color='r', lw=2, label='H3+'),
                   Patch(facecolor='grey', edgecolor='grey', label='Imán')]

ax.legend(handles=legend_elements, loc='lower left')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pylab as plt
from matplotlib import cm
from matplotlib.cm import ScalarMappable
import matplotlib.patches as patches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# generate example data
import pandas as pd

#IMAN
ax = plt.gca()
rect = patches.Rectangle((-10,-10), 20,20,edgecolor = 'grey', facecolor = 'grey', fill = True,)
ax.add_patch(rect)

NUM_PART = 10
files = ['30P.txt', '30H2.txt','30H3.txt']
color = iter(cm.rainbow(np.linspace(0, 1, len(files))))

for file in files:
    data1 = pd.read_csv(file, sep = '\s+', header = None)
    data1 = pd.DataFrame(data1)
    c = next(color)  
    for particle in range(0, NUM_PART-1):
        cero = data1[data1[3] == particle]
        xp0 = cero[0]
        zp0 = cero[2]
        plt.plot(xp0,zp0, color = c)

plt.xlabel('X(mm)')
plt.ylabel('Z(mm)')
plt.title('Desviación en la dirección del protón, H2+ y H3+ a 30keV')
plt.ylim(-45,40)

#legend

legend_elements = [Line2D([0], [0], color='blueviolet', lw=2, label='Protón'),
                   Line2D([0], [0], color='LightGreen', lw=2, label='H2+'),
                   Line2D([0], [0], color='r', lw=2, label='H3+'),
                   Patch(facecolor='grey', edgecolor='grey', label='Imán')]

ax.legend(handles=legend_elements, loc='lower left')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pylab as plt
from matplotlib import cm
from matplotlib.cm import ScalarMappable
import matplotlib.patches as patches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

# generate example data
import pandas as pd

#IMAN
ax = plt.gca()
rect = patches.Rectangle((-10,-10), 20,20,edgecolor = 'grey', facecolor = 'grey', fill = True,)
ax.add_patch(rect)

NUM_PART = 10
files = ['27P.txt', '27H2.txt','27H3.txt']
color = iter(cm.rainbow(np.linspace(0, 1, len(files))))

for file in files:
    data1 = pd.read_csv(file, sep = '\s+', header = None)
    data1 = pd.DataFrame(data1)
    c = next(color)  
    for particle in range(0, NUM_PART-1):
        cero = data1[data1[3] == particle]
        xp0 = cero[0]
        zp0 = cero[2]
        plt.plot(xp0,zp0, color = c)

plt.xlabel('X(mm)')
plt.ylabel('Z(mm)')
plt.title('Desviación en la dirección del protón, H2+ y H3+ a 27keV')
plt.ylim(-45,40)

#legend

legend_elements = [Line2D([0], [0], color='blueviolet', lw=2, label='Protón'),
                   Line2D([0], [0], color='LightGreen', lw=2, label='H2+'),
                   Line2D([0], [0], color='r', lw=2, label='H3+'),
                   Patch(facecolor='grey', edgecolor='grey', label='Imán')]

ax.legend(handles=legend_elements, loc='lower left')

plt.show()

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pylab as plt
from matplotlib import cm
from matplotlib.cm import ScalarMappable
import matplotlib.patches as patches
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

plt.rcParams['font.size'] = 13

# generate example data
import pandas as pd

#IMAN
ax = plt.gca()
rect = patches.Rectangle((-10,-10), 20,20,edgecolor = 'grey', facecolor = 'grey', fill = True,)
ax.add_patch(rect)

NUM_PART = 10
files = ['25P.txt', '25H2.txt','25H3.txt']
color = iter(cm.rainbow(np.linspace(0, 1, len(files))))

for file in files:
    data1 = pd.read_csv(file, sep = '\s+', header = None)
    data1 = pd.DataFrame(data1)
    c = next(color)  
    for particle in range(0, NUM_PART-1):
        cero = data1[data1[3] == particle]
        xp0 = cero[0]
        zp0 = cero[2]
        plt.plot(xp0,zp0, color = c)

plt.xlabel('X(mm)')
plt.ylabel('Z(mm)')
#plt.title('Desviación en la dirección del protón, H2+ y H3+ a 25keV')
plt.ylim(-45,40)

#legend

legend_elements = [Line2D([0], [0], color='blueviolet', lw=2, label='Protón'),
                   Line2D([0], [0], color='LightGreen', lw=2, label='H2+'),
                   Line2D([0], [0], color='r', lw=2, label='H3+'),
                   Patch(facecolor='grey', edgecolor='grey', label='Imán')]

ax.legend(handles=legend_elements, loc='lower left')

plt.show()
